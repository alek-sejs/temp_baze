# %%
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline 
# %matplotlib


#графики встраиваются в блокнот;
#%matplotlib inline - в блокноте, в виде статичного изображения
#%matplotlib - в отдельном окне
# Out:
# Using matplotlib backend: Qt5Agg

# %%
info = pd.read_excel('xxxxx.xlsx')

# %%
info.tail()
# Out:
#        period  gas_m3  elec_kw  average_t
# 32 2017-06-01     448   3571.0       14.1
# 33 2017-07-01     381   3527.0       16.0
# 34 2017-08-01     349   3526.0       16.7
# 35 2017-09-01     571   4470.0       12.8
# 36 2017-10-01     851   4059.0        8.4

# %% [markdown]
# ### Sadalījums pa gadiem

# %%
j14 = info[(info.period >= '2014-10-01') & (info.period <= '2014-12-01')]
j15 = info[(info.period >= '2015-01-01') & (info.period <= '2015-12-01')]
j16 = info[(info.period >= '2016-01-01') & (info.period <= '2016-12-01')]
j17 = info[(info.period >= '2017-01-01') & (info.period <= '2017-12-01')]

# j14.loc[:].plot(kind='area', stacked=False)

# %% [markdown]
# ### PIES

# %%
labels = '2014 (3mēn.)', '2015', '2016', '2017 (10mēn)'
sizes = [j14.gas_m3.sum()/info.gas_m3.sum(), j15.gas_m3.sum()/info.gas_m3.sum(), j16.gas_m3.sum()/info.gas_m3.sum(), j17.gas_m3.sum()/info.gas_m3.sum()  ]
explode = (0.2, 0, 0, 0.2)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.xlabel('gāzes patēriņš', fontsize=14);

plt.show()

# %%
labels = '2014 (3mēn)', '2015', '2016', '2017 (10mēn.)'
sizes = [j14.elec_kw.sum()/info.elec_kw.sum(), j15.elec_kw.sum()/info.elec_kw.sum(), j16.elec_kw.sum()/info.elec_kw.sum(), j17.elec_kw.sum()/info.elec_kw.sum()  ]
explode = (0.2, 0, 0, 0.2)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.xlabel('elektrības patēriņš', fontsize=14);

plt.show()

# %%
plt.plot(info.period, info.gas_m3, color='blue', marker='o', linestyle='--', label='gāzes patēriņš');
plt.plot(info.period, info.elec_kw, color='red', marker='o', linestyle='--', label='elektrības patēriņš');


plt.axvline(x = '2014-10-01',color='lightgray',linestyle='--')
plt.axvline(x = '2015-04-01',color='lightgray',linestyle='--')
plt.axvline(x = '2015-10-01',color='lightgray',linestyle='--')
plt.axvline(x = '2016-04-01',color='lightgray',linestyle='--')
plt.axvline(x = '2016-10-01',color='lightgray',linestyle='--')
plt.axvline(x = '2017-04-01',color='lightgray',linestyle='--')

plt.xticks( rotation = 30)

plt.legend(loc='best');

# %%
t = info[['average_t','gas_m3','elec_kw']].sort_values('average_t')

plt.plot(t.average_t, t.gas_m3, color='blue', marker='o', linestyle='--', label='gāzes patēriņš');
plt.plot(t.average_t, t.elec_kw, color='red', marker='o', linestyle='--', label='elektrības patēriņš');
plt.legend(loc='best');

plt.xlabel('vidējā temperatūra (visi periodi)', fontsize=14);

# %%
j1 = j14[['average_t','gas_m3','elec_kw']].sort_values('average_t')
j2 = j15[['average_t','gas_m3','elec_kw']].sort_values('average_t')
j3 = j16[['average_t','gas_m3','elec_kw']].sort_values('average_t')
j4 = j17[['average_t','gas_m3','elec_kw']].sort_values('average_t')

x1 = j1.average_t
x2 = j2.average_t
x3 = j3.average_t
x4 = j4.average_t


y10 = j1.gas_m3
y11 = j1.elec_kw
y20 = j2.gas_m3
y22 = j2.elec_kw
y30 = j3.gas_m3
y33 = j3.elec_kw
y40 = j4.gas_m3
y44 = j4.elec_kw

plt.subplot(1, 2, 1);
plt.plot(x2, y20, 'o-',label='gāzes patēriņš 2015');
plt.legend(loc='best');

plt.subplot(1, 2, 1);
plt.plot(x3, y30, 'o-',label='gāzes patēriņš 2016');
plt.legend(loc='best');

plt.subplot(1, 2, 1);
plt.plot(x4, y40, 'o-',label='gāzes patēriņš 2017');
plt.legend(loc='best');
# plt.title('Gāzes patēriņš / temp. 2015')
# plt.ylabel('Gāzes patēriņš / temp. 2015')


# plt.subplot(1, 2, 2);
# plt.plot(x2, y22, 'o-');
# plt.legend(loc='best');

# plt.subplot(1, 2, 2);
# plt.plot(x3, y33, 'o-');
# plt.legend(loc='best');


# plt.subplot(1, 2, 2);
# plt.plot(x4, y44, 'o-');
# plt.legend(loc='best');
# # plt.ylabel('Elektrības patēriņš / temp. 2014')









plt.show()

# %%
j1 = j14[['average_t','gas_m3','elec_kw']].sort_values('average_t')
j2 = j15[['average_t','gas_m3','elec_kw']].sort_values('average_t')
j3 = j16[['average_t','gas_m3','elec_kw']].sort_values('average_t')
j4 = j17[['average_t','gas_m3','elec_kw']].sort_values('average_t')

x1 = j1.average_t
x2 = j2.average_t
x3 = j3.average_t
x4 = j4.average_t


y10 = j1.gas_m3
y11 = j1.elec_kw
y20 = j2.gas_m3
y22 = j2.elec_kw
y30 = j3.gas_m3
y33 = j3.elec_kw
y40 = j4.gas_m3
y44 = j4.elec_kw


plt.plot(x2, y20, 'o-',label='gāzes patēriņš 2015');
plt.plot(x3, y30, 'o-',label='gāzes patēriņš 2016');
plt.plot(x4, y40, 'o-',label='gāzes patēriņš 2017');

plt.legend(loc='best');
plt.xlabel('vidējā temperatūra', fontsize=14);

# %%
j1 = j14[['average_t','gas_m3','elec_kw']].sort_values('average_t')
j2 = j15[['average_t','gas_m3','elec_kw']].sort_values('average_t')
j3 = j16[['average_t','gas_m3','elec_kw']].sort_values('average_t')
j4 = j17[['average_t','gas_m3','elec_kw']].sort_values('average_t')

x1 = j1.average_t
x2 = j2.average_t
x3 = j3.average_t
x4 = j4.average_t


y10 = j1.gas_m3
y11 = j1.elec_kw
y20 = j2.gas_m3
y22 = j2.elec_kw
y30 = j3.gas_m3
y33 = j3.elec_kw
y40 = j4.gas_m3
y44 = j4.elec_kw


plt.plot(x2, y22, 'o-',label='elektrības patēriņš 2015');
plt.plot(x3, y33, 'o-',label='elektrības patēriņš 2016');
plt.plot(x4, y44, 'o-',label='elektrības patēriņš 2017');

plt.legend(loc='best');
plt.xlabel('vidējā temperatūra', fontsize=14);

# %% [markdown]
# ### TEST&info from drafts

# %%
x1 = info.period
x2 = info.period

y1 = info.gas_m3
y2 = info.elec_kw


plt.subplot(2, 2, 1)
plt.plot(x1, y1, 'o-')
plt.title('Elektrības un Gāzes patēriņš pa mēnešiem')
plt.ylabel('Damped oscillation')

plt.subplot(2, 2, 4)
plt.plot(x2, y2, '.-')
plt.xlabel('time (s)')
plt.ylabel('Undamped')

plt.xticks( rotation = 30)

plt.show()

# %%
# x1 = np.linspace(0.0, 5.0)
# x2 = np.linspace(0.0, 2.0)

# y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
# y2 = np.cos(2 * np.pi * x2)

# plt.subplot(2, 1, 1)
# plt.plot(x1, y1, 'o-')
# plt.title('A tale of 2 subplots')
# plt.ylabel('Damped oscillation')

# plt.subplot(2, 1, 2)
# plt.plot(x2, y2, '.-')
# plt.xlabel('time (s)')
# plt.ylabel('Undamped')

# plt.show()

# %% [markdown]
# # """
# ===============
# Basic pie chart
# ===============
#
# Demo of a basic pie chart plus a few additional features.
#
# In addition to the basic pie chart, this demo shows a few optional features:
#
#     * slice labels
#     * auto-labeling the percentage
#     * offsetting a slice with "explode"
#     * drop-shadow
#     * custom start angle
#
# Note about the custom start angle:
#
# The default ``startangle`` is 0, which would start the "Frogs" slice on the
# positive x-axis. This example sets ``startangle = 90`` such that everything is
# rotated counter-clockwise by 90 degrees, and the frog slice starts on the
# positive y-axis.
# """
# import matplotlib.pyplot as plt
#
# # Pie chart, where the slices will be ordered and plotted counter-clockwise:
# labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
# sizes = [15, 30, 45, 10]
# explode = (0, 0.1, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')
#
# fig1, ax1 = plt.subplots()
# ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
#         shadow=True, startangle=90)
# ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
#
# plt.show()
